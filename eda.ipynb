# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('cleaned_data.csv')

# %%
data['price'].describe()
# Out:
# count       893.000000
# mean      79907.409854
# std       60880.043823
# min        9999.000000
# 25%       44500.000000
# 50%       61990.000000
# 75%       90990.000000
# max      450039.000000
# Name: price, dtype: float64

# %%
plt.boxplot(data['price'])
plt.show()

# %%
plt.hist(data['price'])
plt.show()

# %%
sns.countplot(x=data['CPU'], data=data)
# Out:
# <Axes: xlabel='CPU', ylabel='count'>

# %%
data.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price                1.000000
# Ram                  0.736924
# Cores                0.710183
# ROM                  0.624741
# resolution_height    0.604748
# resolution_width     0.586042
# Performance_Cores    0.569283
# Threads              0.559870
# spec_rating          0.546391
# PPI                  0.540507
# Efficiency_Cores     0.495389
# Gaming               0.416786
# display_size         0.233815
# Unnamed: 0           0.162390
# warranty             0.117101
# Name: price, dtype: float64

# %%
sns.heatmap(data[['Cores','Threads','Performance_Cores','Efficiency_Cores','Ram','price']].corr(),
            annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x='Processor Family',y = 'price', data=data)
# Out:
# <Axes: xlabel='Processor Family', ylabel='price'>

# %%
sns.barplot(x='GPU_Series',y = 'price', data=data)
# Out:
# <Axes: xlabel='GPU_Series', ylabel='price'>

# %%
sns.barplot(x = 'Gaming',y = 'price', data=data)
# Out:
# <Axes: xlabel='Gaming', ylabel='price'>

# %%
sns.barplot(x = 'ROM_type',y = 'price', data=data)
# Out:
# <Axes: xlabel='ROM_type', ylabel='price'>

# %%
sns.barplot(x = 'OS',y = 'price', data=data)
# Out:
# <Axes: xlabel='OS', ylabel='price'>

# %%
sns.scatterplot(x = 'PPI', y = 'price', data=data)
# Out:
# <Axes: xlabel='PPI', ylabel='price'>

# %%
sns.boxplot(x='Ram_type', y='price', data=data)
# Out:
# <Axes: xlabel='Ram_type', ylabel='price'>
